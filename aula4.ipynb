# %% [markdown]
# # Probabilidade e Inteligência Artificial

# %% [markdown]
# - Estatística é uma área da matemática
# - Probabilidade é uma área da estatística
# - IA Classica x IA Estatística

# %% [markdown]
# ### Filmes e Séries

# %% [markdown]
# - IA Classica: Alan Turing o Eu Robô, AI Inteligência Artificial (Jogo da Imitação)
# - IA Estatística: Robocop (Consegue prever crimes)

# %% [markdown]
# ![transferir (2).png](<attachment:transferir (2).png>)

# %% [markdown]
# ### IA Clássica (Simbólica e Lógica)

# %% [markdown]
# - O Jogo da Imitação (The Imitation Game): Teoria da Computação, Teste de Turing
# - Ex Machina: Teste de Turing, IA Forte (Intelecto Completo igual ao humano)
# - 2001: Uma Odisseia no Espaço (2001: A Space Odyssey)
# - Eu, Robô (I, Robot)
# - Acompanhamente perfeita
# - Blade Runner 2049

# %% [markdown]
# ![transferir (3).png](<attachment:transferir (3).png>)

# %% [markdown]
# ### IA Estatística (Aprendizado de Máquina e Dados)

# %% [markdown]
# - Minority Report - A Lei do Futuro
# - RoboCop (versão de 2014)
# - Moneyball - O Homem que Mudou o Jogo

# %% [markdown]
# ![transferir (4).png](<attachment:transferir (4).png>)

# %% [markdown]
# ![transferir (5).png](<attachment:transferir (5).png>)

# %% [markdown]
# ![transferir (6).png](<attachment:transferir (6).png>)

# %%
import numpy as np

# %%
import pandas as pd

# %%
dados = np.loadtxt('datasets/cpa - cpa-cont-pop-agregada.csv', delimiter=',',skiprows=1,dtype=str)

# %%
dados
# Out:
# array([['XV', 'Recanto das Emas', '105.865', '50.711', '55.154',
#         '28.018', '11.465', '8600'],
#        ['XII', 'Samambaia', '247.629', '119.676', '127.953', '55320',
#         '11776', '24737'],
#        ['III', 'Taguatinga', '210.498', '96.824', '113.674', '34.298',
#         '36.178', '44034'],
#        ['XXI', 'Riacho Fundo 2', '72.988', '35.846', '37.142', '13.376',
#         '4.133', '5952'],
#        ['XXXII', 'Sol Nascente', '93.217', '46.364', '46.853', '22.430',
#         '4.235', '2.681'],
#        ['XXX', 'Vicente Pires', '78.561', '38.865', '39.696', '13.437',
#         '9.013', '17031'],
#        ['IX', 'CeilÃ¢ndia', '350.347', '166.025', '184.322', '68.197',
#         '43.985', '21716'],
#        ['XVII', 'Riacho Fundo I', '44.464', '  21.096 ', '  23.368 ',
#         '7.955', '4.737', '8.547']], dtype='<U16')

# %%
Moscow = dados[:,1]

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/cpa - cpa-cont-pop-agregada.csv')

# %%
df.head()
# Out:
#    RA_ID           Nome_RA  Populacao_Total  Populacao_Homens  \
# 0     XV  Recanto das Emas          105.865            50.711
# 1    XII         Samambaia          247.629           119.676
# 2    III        Taguatinga          210.498            96.824
# 3    XXI    Riacho Fundo 2           72.988            35.846
# 4  XXXII      Sol Nascente           93.217            46.364
#
#    Populacao_Mulheres  Populacao_Criancas  Populacao_Idosos  \
# 0              55.154              28.018            11.465
# 1             127.953           55320.000         11776.000
# 2             113.674              34.298            36.178
# 3              37.142              13.376             4.133
# 4              46.853              22.430             4.235
#
#    Graduação Completa
# 0            8600.000
# 1           24737.000
# 2           44034.000
# 3            5952.000
# 4               2.681

# %%
df.tail()
# Out:
#    RA_ID         Nome_RA  Populacao_Total  Populacao_Homens  \
# 3    XXI  Riacho Fundo 2           72.988            35.846
# 4  XXXII    Sol Nascente           93.217            46.364
# 5    XXX   Vicente Pires           78.561            38.865
# 6     IX       Ceilândia          350.347           166.025
# 7   XVII  Riacho Fundo I           44.464            21.096
#
#    Populacao_Mulheres  Populacao_Criancas  Populacao_Idosos  \
# 3              37.142              13.376             4.133
# 4              46.853              22.430             4.235
# 5              39.696              13.437             9.013
# 6             184.322              68.197            43.985
# 7              23.368               7.955             4.737
#
#    Graduação Completa
# 3            5952.000
# 4               2.681
# 5           17031.000
# 6           21716.000
# 7               8.547

# %%
import pandas as pd
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 8))
plt.barh(df['Nome_RA'], df['Populacao_Total'])
plt.xlabel('População Total')
plt.show()
