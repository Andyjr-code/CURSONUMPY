# %% [markdown]
# # O que vamos aprender?

# %% [markdown]
# - O que é Numpy
# - Manipular arrays (ndarray)
# - Indexação
# - Operações vetorizadas
# - Algebra Linear e Estatística (Probabilidade e Est. Bayesiana)
# - Performance: Numpy vs. Lista Nativas Python
# - Boas Práticas e solução do projeto

# %%
print("Thomas Bayes vai revirar no túmulo!")
# Out:
# Thomas Bayes vai revirar no túmulo!

# %% [markdown]
# ### Por que o Numpy é o coração da ciencia de dados em Python?

# %% [markdown]
# - Pandas
# - Sciki-learn
# - Tensorflow (redes neurais)
# - Matplotlib

# %%
import numpy as np

# %% [markdown]
# - Lista do python x Array do Numpy

# %% [markdown]
# - Vetor ou Matriz Unidimensional

# %% [markdown]
# ### Porque o Numpy Array e mais rapido que uma lista python

# %% [markdown]
# - Lista e a sacola do supermercado
# - Array do numpy - caixa de ovos
# - C e Fortran: 50x
# - O Numpy permite a vertorizacao

# %% [markdown]
# # Aula 1 - Download de DataSets

# %% [markdown]
# - Iris
# - Petrobras (acoes)
# - Macas

# %%
np.__version__
# Out:
# '2.3.5'

# %%
np.loadtxt('datasets/andy-iris.csv', delimiter=',' ,skiprows=1, usecols=(0,1,2,3))
# Out:
# array([[  1. ,   5.1,   3.5,   1.4],
#        [  2. ,   4.9,   3. ,   1.4],
#        [  3. ,   4.7,   3.2,   1.3],
#        [  4. ,   4.6,   3.1,   1.5],
#        [  5. ,   5. ,   3.6,   1.4],
#        [  6. ,   5.4,   3.9,   1.7],
#        [  7. ,   4.6,   3.4,   1.4],
#        [  8. ,   5. ,   3.4,   1.5],
#        [  9. ,   4.4,   2.9,   1.4],
#        [ 10. ,   4.9,   3.1,   1.5],
#        [ 11. ,   5.4,   3.7,   1.5],
#        [ 12. ,   4.8,   3.4,   1.6],
#        [ 13. ,   4.8,   3. ,   1.4],
#        [ 14. ,   4.3,   3. ,   1.1],
#        [ 15. ,   5.8,   4. ,   1.2],
#        [ 16. ,   5.7,   4.4,   1.5],
#        [ 17. ,   5.4,   3.9,   1.3],
#        [ 18. ,   5.1,   3.5,   1.4],
#        [ 19. ,   5.7,   3.8,   1.7],
#        [ 20. ,   5.1,   3.8,   1.5],
#        [ 21. ,   5.4,   3.4,   1.7],
#        [ 22. ,   5.1,   3.7,   1.5],
#        [ 23. ,   4.6,   3.6,   1. ],
#        [ 24. ,   5.1,   3.3,   1.7],
#        [ 25. ,   4.8,   3.4,   1.9],
# ...

# %% [markdown]
# # Nossos DataSets

# %% [markdown]
# #### Iris (Nosso hello world! Dataset)

# %% [markdown]
# - Classico - DC e ML
# - Edgar Anderson, Ronald A. Fisher em 1936
# - 150 amostras - três espécies (setosa, versicolor, virginica)
# - Comprimento e a largura (sepal e petal)

# %% [markdown]
# #### Petrobras.xlsx

# %% [markdown]
# - Mercado Financeiro- o retrono financeiro
# - Rentabilidade de um ativo financeiro em relação ao outro
# - Volatividade de um ativo em relação ao outro
# - 5 minutos planilha é atualizada

# %% [markdown]
# ret = preco(i-1) / preco (i-1)

# %% [markdown]
# #### Apples.csv

# %% [markdown]
# - Cada linha é uma cidade da Russia
# - Cada culana uma data (mes-ano) - 12 anos.

# %% [markdown]
# #### Bibliotecas

# %% [markdown]
# - Numpy
# - Scipy
# - MatplotLib

# %% [markdown]
# #### EDA Iris Com NumPy

# %%
data_iris = np.loadtxt('datasets/andy-iris.csv', delimiter=',' ,skiprows=1, usecols=(0,1,2,3))

# %%
data_iris[:5]
# Out:
# array([[1. , 5.1, 3.5, 1.4],
#        [2. , 4.9, 3. , 1.4],
#        [3. , 4.7, 3.2, 1.3],
#        [4. , 4.6, 3.1, 1.5],
#        [5. , 5. , 3.6, 1.4]])

# %%
print(data_iris[:5])
# Out:
# [[1.  5.1 3.5 1.4]
#  [2.  4.9 3.  1.4]
#  [3.  4.7 3.2 1.3]
#  [4.  4.6 3.1 1.5]
#  [5.  5.  3.6 1.4]]

# %%
data_iris.shape
# Out:
# (150, 4)

# %%
data_iris.dtype
# Out:
# dtype('float64')

# %%
# somar a primeira linha
print(f"Soma da primeira linha {data_iris[0].sum()}")
# Out:
# Soma da primeira linha 11.0

# %%
# Somar a primeira coluna
print(f"soma da primeira coluna: {data_iris[:, 0].sum()}")
# Out:
# soma da primeira coluna: 11325.0

# %% [markdown]
# - std() - desvio padrão
# - max() - máximo
# - min() - mínimo
# - sum() - soma
# - prod() - produto
# - var() - variância

# %% [markdown]
# #### Conclusão Aula 2 NumPy

# %% [markdown]
# # Criando um Histograma

# %%
! pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
data_iris
# Out:
# array([[  1. ,   5.1,   3.5,   1.4],
#        [  2. ,   4.9,   3. ,   1.4],
#        [  3. ,   4.7,   3.2,   1.3],
#        [  4. ,   4.6,   3.1,   1.5],
#        [  5. ,   5. ,   3.6,   1.4],
#        [  6. ,   5.4,   3.9,   1.7],
#        [  7. ,   4.6,   3.4,   1.4],
#        [  8. ,   5. ,   3.4,   1.5],
#        [  9. ,   4.4,   2.9,   1.4],
#        [ 10. ,   4.9,   3.1,   1.5],
#        [ 11. ,   5.4,   3.7,   1.5],
#        [ 12. ,   4.8,   3.4,   1.6],
#        [ 13. ,   4.8,   3. ,   1.4],
#        [ 14. ,   4.3,   3. ,   1.1],
#        [ 15. ,   5.8,   4. ,   1.2],
#        [ 16. ,   5.7,   4.4,   1.5],
#        [ 17. ,   5.4,   3.9,   1.3],
#        [ 18. ,   5.1,   3.5,   1.4],
#        [ 19. ,   5.7,   3.8,   1.7],
#        [ 20. ,   5.1,   3.8,   1.5],
#        [ 21. ,   5.4,   3.4,   1.7],
#        [ 22. ,   5.1,   3.7,   1.5],
#        [ 23. ,   4.6,   3.6,   1. ],
#        [ 24. ,   5.1,   3.3,   1.7],
#        [ 25. ,   4.8,   3.4,   1.9],
# ...

# %%
plt.hist(data_iris[:, 1], bins=10)
plt.title("Histograma do comprimento da sépala")
plt.xlabel("sepal Lenngt (cm)")
plt.ylabel("Frequência")
# Out:
# Text(0, 0.5, 'Frequência')

# %% [markdown]
# ### Histograma sepal_width

# %%
plt.hist(data_iris[:, 2], bins=10)
plt.title("Histograma do comprimento da sépala")
plt.xlabel("Sepal Width (cm)")
plt.ylabel("Frequência")
# Out:
# Text(0, 0.5, 'Frequência')

# %%
plt.hist(data_iris[:, 3], bins=10)
plt.title("Histograma do comprimento da sépala")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequência")
# Out:
# Text(0, 0.5, 'Frequência')
